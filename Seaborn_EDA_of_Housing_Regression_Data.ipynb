# %% [markdown]
# <a href="https://colab.research.google.com/github/vicperotti/BANA780/blob/main/Seaborn_EDA_of_Housing_Regression_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This example demonstrates the power of seaborn to do EDA. We work on the Housing Regression Dataset from Kaggle. https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# Documentation on seaborn can be found here: https://seaborn.pydata.org/api.html

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('housingtrain.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# Pandas dataframe has some of its own easy plotting functions, but seaborn is more tailored to EDA

# %%
df['SalePrice'].hist()

# %%
sns.histplot(data=df,x='SalePrice')

# %%
sns.countplot(data=df,x='BldgType')

# %%
sns.lineplot(data=df,x='YrSold',y='SalePrice')

# %%
sns.scatterplot(data=df,x='OverallQual',y='SalePrice')

# %%
sns.boxplot(data=df,x='OverallQual',y='SalePrice')

# %% [markdown]
# There are MANY ways to visualize a numerical (SalePrice) variable versus a categorical variable. Below are stripplot, catplot, violinplot and barplot.

# %%
sns.stripplot(data=df,x='MSZoning',y='SalePrice')

# %%
sns.boxplot(data=df,x='MSZoning',y='SalePrice')

# %%
sns.violinplot(data=df,x='MSZoning',y='SalePrice')

# %%
sns.scatterplot(data=df,x='LotArea',y='SalePrice',hue='MSZoning')
#color scatterplot with MSZoning

# %%
sns.barplot(data=df,x='SalePrice',y='Neighborhood',ci=None)
#remove confidence interval bars

# %%
sns.catplot(data=df,x='BldgType',y='SalePrice',col='MSZoning')
#faceting using col
#this is hard to read....

# %%
littledf = df[(df['MSZoning'] == 'RL') | (df['MSZoning'] == 'RM')]
#I find this easier in tidyverse but
#but here we can pluck out two categories to work with to make a smaller df
#called littledf

# %%
sns.catplot(data=littledf,x='BldgType',y='SalePrice',col='MSZoning')

# %%
#changing the size of a figure is a good skill
#see https://www.delftstack.com/howto/seaborn/size-of-seaborn-plot/

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,10))
p = sns.catplot(data=df,x='BldgType',y='SalePrice',col='MSZoning')
#you can open this image in a new tab to see how big it is!
